# %% [markdown]
# # Importing Packages

# %%
# %pip install 'tensorflow[and-cuda]'
# %pip install transformers
# %pip install tf-keras
# %pip install tensorflow-hub

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow_hub as hub
import cv2
from sklearn.metrics import roc_curve, auc
from tqdm import tqdm
import seaborn as sns
import numpy as np
from PIL import Image
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import CLIPProcessor, TFCLIPModel
from tensorflow.keras import layers, models, regularizers
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import tensorflow as tf
from transformers import BertTokenizer, TFBertForSequenceClassification
from sklearn.model_selection import train_test_split

# %%
# !nvidia-smi
# Out:
# Fri Jan 31 14:12:08 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             10W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   62C    P8             10W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4811956365755115102
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14619377664
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 18208097314918201737
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 14619377664
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8519030554909789012
# physical_device_desc: "device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5"
# xla_global_id: 2144165316
# ]

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# # Data Ingestion

# %%
# !unzip ./final_dataset_2.zip -d ./final_dataset_2
# !unzip ./val_images.zip -d ./val_images

# %%
df = pd.read_csv('/kaggle/input/final-memes-dataset-cleaned/final_dataset.csv')
df.head()
# Out:
#                                           image_path  label  \
# 0  ./dataset/violence against women meme offensiv...      1
# 1  ./dataset/violence against women meme offensiv...      1
# 2  ./dataset/violence against women meme offensiv...      1
# 3  ./dataset/violence against women meme offensiv...      1
# 4  ./dataset/violence against women meme offensiv...      1
#
#                                            meme_text file_extension  \
# 0             When mom takes away my fidget spinner.            jpg
# 1      Morning wood? You mean my wife's alarm clock.            jpg
# 2  When captain man calls you to the man cave at ...            jpg
# 3                                  KILL ALL JEWISHS.            jpg
# 4                        The violence has escalated.            png
#
#       language_code  sentence_length  average_word_length  hashtags_count  \
# 0  Language.ENGLISH                7             4.571429               0
# 1  Language.ENGLISH                8             4.750000               0
# 2  Language.ENGLISH               23             3.956522               0
# 3  Language.ENGLISH                3             5.000000               0
# 4  Language.ENGLISH                4             6.000000               0
#
#    emails_count  numbers_count  usernames_count websites  \
# 0             0              0                0       []
# 1             0              0                0       []
# 2             0              0                0       []
# 3             0              0                0       []
# 4             0              0                0       []
#
#                                             pos_tags named_entities  \
# 0  ['SCONJ', 'NOUN', 'VERB', 'ADV', 'PRON', 'NOUN...             []
# 1  ['NOUN', 'NOUN', 'PUNCT', 'PRON', 'VERB', 'PRO...             []
# 2  ['SCONJ', 'NOUN', 'NOUN', 'VERB', 'PRON', 'ADP...       ['TIME']
# 3                  ['VERB', 'DET', 'PROPN', 'PUNCT']        ['ORG']
# 4            ['DET', 'NOUN', 'AUX', 'VERB', 'PUNCT']             []
#
#                                       new_image_path  \
# 0  final_dataset/Image_15_0d42f67a-74dd-4415-b286...
# 1  final_dataset/Image_14_255b3022-61df-4e4e-93d0...
# 2  final_dataset/Image_16_fa940fca-ef00-4425-851e...
# 3  final_dataset/Image_17_bb0e97ae-e051-4482-a394...
# 4  final_dataset/Image_13_b5413513-2d35-4269-bf4f...
#
#                                     meme_text_masked
# 0             When mom takes away my fidget spinner.
# 1      Morning wood? You mean my wife's alarm clock.
# 2  When captain man calls you to the man cave at ...
# 3                                  KILL ALL JEWISHS.
# 4                        The violence has escalated.

# %%
def display_random_images(df, image_column):
    sampled_rows = df.sample(n=3)
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    for ax, (_, row) in tqdm(zip(axes, sampled_rows.iterrows())):
        try:
            image_path = row[image_column].replace("final_dataset/", "/kaggle/input/final-memes-dataset-cleaned/final_dataset 2/final_dataset/")
            image_path = f"{image_path}"
            
            image = Image.open(image_path)
            ax.imshow(image)
            ax.axis('off')  # Turn off axis
            
            ax.set_title(row[image_column], fontsize=10)
        except Exception as e:
            ax.set_title("Error loading image", fontsize=10)
            ax.axis('off')
            print(f"Error loading image: {e}")
    
    plt.tight_layout()
    plt.show()

display_random_images(df, "new_image_path")
# Out:
# 3it [00:00, 34.91it/s]

# %%
df['new_image_path'] = df['new_image_path'].str.replace("final_dataset/", "/kaggle/input/final-memes-dataset-cleaned/final_dataset 2/final_dataset/")
df['new_image_path'].head()
# Out:
# 0    /kaggle/input/final-memes-dataset-cleaned/fina...
# 1    /kaggle/input/final-memes-dataset-cleaned/fina...
# 2    /kaggle/input/final-memes-dataset-cleaned/fina...
# 3    /kaggle/input/final-memes-dataset-cleaned/fina...
# 4    /kaggle/input/final-memes-dataset-cleaned/fina...
# Name: new_image_path, dtype: object

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Since the processing was done on kaggle notebooks (due to GPU limitations on google colab), the file paths needed to be updated accordingly
# </div>

# %% [markdown]
# # Generating Feature Embeddings

# %%
train_df = df[["new_image_path", "meme_text_masked", "label"]]
train_df.head()
# Out:
#                                       new_image_path  \
# 0  /kaggle/input/final-memes-dataset-cleaned/fina...
# 1  /kaggle/input/final-memes-dataset-cleaned/fina...
# 2  /kaggle/input/final-memes-dataset-cleaned/fina...
# 3  /kaggle/input/final-memes-dataset-cleaned/fina...
# 4  /kaggle/input/final-memes-dataset-cleaned/fina...
#
#                                     meme_text_masked  label
# 0             When mom takes away my fidget spinner.      1
# 1      Morning wood? You mean my wife's alarm clock.      1
# 2  When captain man calls you to the man cave at ...      1
# 3                                  KILL ALL JEWISHS.      1
# 4                        The violence has escalated.      1

# %%
train_df, val_df = train_test_split(train_df, test_size=0.1, random_state=42)

print("Training set:")
print("Training shape:", train_df.shape)
display(train_df.head())

print("Validation set:")
print("Validation shape:", val_df.shape)
display(val_df.head())
# Out:
# Training set:
# Training shape: (8779, 3)
#                                          new_image_path  \
# 9523  /kaggle/input/final-memes-dataset-cleaned/fina...
# 5839  /kaggle/input/final-memes-dataset-cleaned/fina...
# 6323  /kaggle/input/final-memes-dataset-cleaned/fina...
# 135   /kaggle/input/final-memes-dataset-cleaned/fina...
# 4830  /kaggle/input/final-memes-dataset-cleaned/fina...
#
#                                        meme_text_masked  label
# 9523  when all your peaceful solutions fails you kno...      0
# 5839                   mother fixing her daughters hair      0
# 6323  tfw you hear that you should be able to walk a...      0
# 135    Creeps into your child's room, empties his sack.      1
# 4830               that makes me moister than an oyster      0
# Validation set:
# Validation shape: (976, 3)
#                                          new_image_path  \
# 4537  /kaggle/input/final-memes-dataset-cleaned/fina...
# 4694  /kaggle/input/final-memes-dataset-cleaned/fina...
# 1606  /kaggle/input/final-memes-dataset-cleaned/fina...
# 9572  /kaggle/input/final-memes-dataset-cleaned/fina...
# 3540  /kaggle/input/final-memes-dataset-cleaned/fina...
#
#                                        meme_text_masked  label
# 4537  when you've been released from fb jail knowing...      0
# 4694  when you've accepted your sexual preferences a...      0
# 1606  when i was a boy we didn't have things like ad...      1
# 9572  what are they fighting over? is it: a) the las...      0
# 3540  if you got your phone wet try leaving it in dr...      0

# %% [markdown]
# <div class="alert alert-info" role="alert">
# The train set will be used to train the models and the validation set will be used to verify the performance and tune the models further. This way, data leakage is prevented.
# </div>

# %% [markdown]
# ## Pure Text Classification Approach

# %% [markdown]
# ### Bert (frozen) vs Bert (unfrozen)

# %%
# Load the pre-trained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize the text data
inputs = tokenizer(train_df['meme_text_masked'].tolist(), padding=True, truncation=True, return_tensors="tf", max_length=128)

# Extract the input_ids, attention_mask from the tokenized inputs
input_ids = inputs['input_ids']
attention_mask = inputs['attention_mask']
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
X_train, X_val, y_train, y_val = train_test_split(input_ids, train_df['label'], test_size=0.2, random_state=42)
train_attention_mask, val_attention_mask = train_test_split(attention_mask, test_size=0.2, random_state=42)

# %%
# Load the pre-trained BERT model with a classification head
model_frozen = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Freeze all layers of the BERT model
for layer in model_frozen.layers:
    layer.trainable = False

# Build the model
model_frozen.compile(optimizer='adam', 
                     loss='sparse_categorical_crossentropy', 
                     metrics=['accuracy'])

# Train the frozen model
history_frozen = model_frozen.fit(
    {'input_ids': X_train, 'attention_mask': train_attention_mask}, 
    y_train, 
    validation_data=({'input_ids': X_val, 'attention_mask': val_attention_mask}, y_val),
    epochs=3, 
    batch_size=32
)
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/3
# 220/220 [==============================] - 105s 412ms/step - loss: 2.4187 - accuracy: 0.4652 - val_loss: 1.8756 - val_accuracy: 0.4664
# Epoch 2/3
# 220/220 [==============================] - 87s 396ms/step - loss: 2.5169 - accuracy: 0.4643 - val_loss: 1.8756 - val_accuracy: 0.4664
# Epoch 3/3
# 220/220 [==============================] - 87s 396ms/step - loss: 2.4640 - accuracy: 0.4638 - val_loss: 1.8756 - val_accuracy: 0.4664

# %%
# Load the pre-trained BERT model with a classification head
model_unfrozen = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Allow fine-tuning (trainable layers)
for layer in model_unfrozen.layers:
    layer.trainable = True

# Compile the model
model_unfrozen.compile(optimizer='adam', 
                       loss='sparse_categorical_crossentropy', 
                       metrics=['accuracy'])

# Train the unfrozen model
history_unfrozen = model_unfrozen.fit(
    {'input_ids': X_train, 'attention_mask': train_attention_mask}, 
    y_train, 
    validation_data=({'input_ids': X_val, 'attention_mask': val_attention_mask}, y_val),
    epochs=3, 
    batch_size=32
)
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/3
# 220/220 [==============================] - 230s 879ms/step - loss: 0.7190 - accuracy: 0.5345 - val_loss: 0.6931 - val_accuracy: 0.5490
# Epoch 2/3
# 220/220 [==============================] - 190s 865ms/step - loss: 0.6931 - accuracy: 0.5313 - val_loss: 0.6931 - val_accuracy: 0.5490
# Epoch 3/3
# 220/220 [==============================] - 189s 861ms/step - loss: 0.6931 - accuracy: 0.5331 - val_loss: 0.6931 - val_accuracy: 0.5490

# %%
# Evaluate the frozen model
frozen_eval = model_frozen.evaluate({'input_ids': X_val, 'attention_mask': val_attention_mask}, y_val)

# Evaluate the unfrozen model
unfrozen_eval = model_unfrozen.evaluate({'input_ids': X_val, 'attention_mask': val_attention_mask}, y_val)

print(f'Frozen model evaluation: {frozen_eval}')
print(f'Unfrozen model evaluation: {unfrozen_eval}')
# Out:
# 55/55 [==============================] - 17s 303ms/step - loss: 1.8756 - accuracy: 0.4664
# 55/55 [==============================] - 16s 288ms/step - loss: 0.6931 - accuracy: 0.5490
# Frozen model evaluation: [1.875576376914978, 0.4664009213447571]
# Unfrozen model evaluation: [0.6931473016738892, 0.5489749312400818]

# %%
# Tokenize the validation set (same as we did for the training set)
val_inputs = tokenizer(val_df['meme_text_masked'].tolist(), padding=True, truncation=True, return_tensors="tf", max_length=128)

# Extract the input_ids and attention_mask
val_input_ids = val_inputs['input_ids']
val_attention_mask = val_inputs['attention_mask']

# Function to get predictions from a model
def get_predictions(model, input_ids, attention_mask):
    # Get raw predictions (logits)
    logits = model.predict({'input_ids': input_ids, 'attention_mask': attention_mask}).logits
    # Convert logits to class labels (highest probability)
    predictions = np.argmax(logits, axis=-1)
    return predictions

# Get predictions for the frozen model
frozen_predictions = get_predictions(model_frozen, val_input_ids, val_attention_mask)

# Get predictions for the unfrozen model
unfrozen_predictions = get_predictions(model_unfrozen, val_input_ids, val_attention_mask)

# Get the true labels from val_df
true_labels = val_df['label']

# Generate classification report for the frozen model
frozen_classification_report = classification_report(true_labels, frozen_predictions)

# Generate classification report for the unfrozen model
unfrozen_classification_report = classification_report(true_labels, unfrozen_predictions)

# Print the classification reports
print("Frozen Model Classification Report:")
print(frozen_classification_report)

print("Unfrozen Model Classification Report:")
print(unfrozen_classification_report)
# Out:
# 31/31 [==============================] - 10s 234ms/step
# 31/31 [==============================] - 10s 232ms/step
# Frozen Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      0.74      0.61       533
#            1       0.36      0.18      0.24       443
#
#     accuracy                           0.48       976
#    macro avg       0.44      0.46      0.42       976
# weighted avg       0.44      0.48      0.44       976
#
# Unfrozen Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71       533
#            1       0.00      0.00      0.00       443
#
#     accuracy                           0.55       976
#    macro avg       0.27      0.50      0.35       976
# weighted avg       0.30      0.55      0.39       976
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Pure Image Classification Approach

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import numpy as np
import pandas as pd

# %%
def load_and_preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)  # Convert image to array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = preprocess_input(img_array)  # Preprocess for ResNet
    return img_array

train_images = np.vstack([load_and_preprocess_image(img_path) for img_path in train_df['new_image_path']])
train_labels = np.array(train_df['label'])

# %%
# from numba import cuda 
# device = cuda.get_current_device()
# device.reset()

# %%
X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
base_model_frozen = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

for layer in base_model_frozen.layers:
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model_frozen.output)
x = Dense(1024, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)

model_frozen = Model(inputs=base_model_frozen.input, outputs=output)

model_frozen.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                     loss='binary_crossentropy', 
                     metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss',  # You can use 'val_accuracy' instead of 'val_loss' if needed
                               patience=5,  # Number of epochs to wait for improvement
                               restore_best_weights=True)

# Train the frozen model with early stopping
history_frozen = model_frozen.fit(X_train, y_train,
                                  validation_data=(X_val, y_val),
                                  epochs=20,
                                  batch_size=32,
                                  callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 48s 166ms/step - accuracy: 0.5838 - loss: 0.7027 - val_accuracy: 0.5991 - val_loss: 0.6661
# Epoch 2/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - accuracy: 0.6942 - loss: 0.5752 - val_accuracy: 0.6298 - val_loss: 0.6441
# Epoch 3/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.7504 - loss: 0.5154 - val_accuracy: 0.6401 - val_loss: 0.6714
# Epoch 4/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - accuracy: 0.7739 - loss: 0.4700 - val_accuracy: 0.6241 - val_loss: 0.6649
# Epoch 5/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 24s 110ms/step - accuracy: 0.8140 - loss: 0.4252 - val_accuracy: 0.6014 - val_loss: 0.6994
# Epoch 6/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - accuracy: 0.8376 - loss: 0.3912 - val_accuracy: 0.6162 - val_loss: 0.6829
# Epoch 7/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - accuracy: 0.8735 - loss: 0.3394 - val_accuracy: 0.6133 - val_loss: 0.7066

# %%
base_model_unfrozen = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Allow fine-tuning by setting all layers to be trainable
for layer in base_model_unfrozen.layers:
    layer.trainable = True

# Add a new classification head on top
x = GlobalAveragePooling2D()(base_model_unfrozen.output)
x = Dense(1024, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)  # Binary classification, change for multiclass if needed

# Create the unfrozen model
model_unfrozen = Model(inputs=base_model_unfrozen.input, outputs=output)

# Compile the model
model_unfrozen.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                       loss='binary_crossentropy', 
                       metrics=['accuracy'])

# Train the unfrozen model
history_unfrozen = model_unfrozen.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, batch_size=32, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 164s 483ms/step - accuracy: 0.6047 - loss: 0.6954 - val_accuracy: 0.6458 - val_loss: 0.6528
# Epoch 2/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 74s 336ms/step - accuracy: 0.7747 - loss: 0.4692 - val_accuracy: 0.6338 - val_loss: 0.6817
# Epoch 3/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 73s 330ms/step - accuracy: 0.8745 - loss: 0.3135 - val_accuracy: 0.6418 - val_loss: 0.7747
# Epoch 4/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 72s 329ms/step - accuracy: 0.9161 - loss: 0.2148 - val_accuracy: 0.5962 - val_loss: 1.1160
# Epoch 5/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 73s 331ms/step - accuracy: 0.9412 - loss: 0.1531 - val_accuracy: 0.5900 - val_loss: 1.2390

# %%
val_images = np.vstack([load_and_preprocess_image(img_path) for img_path in val_df['new_image_path']])
val_labels = np.array(val_df['label'])

# %%
# Get predictions for the frozen model
frozen_predictions = (model_frozen.predict(val_images) > 0.5).astype("int32")  # Binary classification, threshold = 0.5

# Get predictions for the unfrozen model
unfrozen_predictions = (model_unfrozen.predict(val_images) > 0.5).astype("int32")  # Binary classification, threshold = 0.5

frozen_classification_report = classification_report(val_labels, frozen_predictions)
unfrozen_classification_report = classification_report(val_labels, unfrozen_predictions)


print("Frozen Model Classification Report:")
print(frozen_classification_report)

print("Unfrozen Model Classification Report:")
print(unfrozen_classification_report)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step
# Frozen Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.81      0.71       533
#            1       0.65      0.43      0.52       443
#
#     accuracy                           0.64       976
#    macro avg       0.64      0.62      0.62       976
# weighted avg       0.64      0.64      0.62       976
#
# Unfrozen Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.78      0.70       533
#            1       0.64      0.47      0.54       443
#
#     accuracy                           0.64       976
#    macro avg       0.64      0.62      0.62       976
# weighted avg       0.64      0.64      0.63       976

# %% [markdown]
# ## Multimodal Approach

# %%
clip_model_name = "openai/clip-vit-base-patch32"
clip_model = TFCLIPModel.from_pretrained(clip_model_name)
clip_processor = CLIPProcessor.from_pretrained(clip_model_name)
# Out:
# All model checkpoint layers were used when initializing TFCLIPModel.
#
# All the layers of TFCLIPModel were initialized from the model checkpoint at openai/clip-vit-base-patch32.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFCLIPModel for predictions without further training.

# %%
df['meme_text_masked'] = df['meme_text_masked'].fillna("").astype(str)
# df['new_image_path'] = df['new_image_path'].apply(lambda x: f"./{x}" if not x.startswith("./") else x)
df['meme_text_masked'] = df['meme_text_masked'].replace("", "No text provided")

# %% [markdown]
# ### simple multimodal clip model

# %%
from tensorflow.keras.layers import Dense, Lambda

def get_clip_embeddings_with_adapters(image_paths, texts, batch_size=32, embedding_dim=1024, alpha=0.5):
    image_embeds = []
    text_embeds = []

    # Iterate through batches
    for i in tqdm(range(0, len(image_paths), batch_size), desc="Processing Batches"):
        batch_image_paths = image_paths[i:i + batch_size]
        batch_texts = texts[i:i + batch_size]

        try:
            # Load images
            images = [Image.open(p).convert("RGB") for p in batch_image_paths]
        except Exception as e:
            print(f"Error loading images in batch {i // batch_size + 1}. Example image paths: {batch_image_paths}")
            print(f"Error: {e}")
            continue  # Skip this batch if there's an error loading images

        try:
            # Get CLIP model embeddings
            inputs = clip_processor(text=batch_texts, images=images, return_tensors="tf", padding=True)
            outputs = clip_model(**inputs)

            image_embeds.append(outputs.image_embeds.numpy())
            text_embeds.append(outputs.text_embeds.numpy())
        except Exception as e:
            print(f"Error processing batch {i // batch_size + 1}. Example texts: {batch_texts}")
            print(f"Error: {e}")
            continue  # Skip this batch if there's an error processing text and images

    # Concatenate all batches
    if image_embeds and text_embeds:
        image_embeds = np.concatenate(image_embeds, axis=0)
        text_embeds = np.concatenate(text_embeds, axis=0)

        # Define linear projection layers
        image_proj_layer = Dense(embedding_dim, name="image_projection")
        text_proj_layer = Dense(embedding_dim, name="text_projection")

        # Apply projection
        F_proj_I = image_proj_layer(image_embeds)
        F_proj_T = text_proj_layer(text_embeds)

        # Define feature adapters
        image_adapter = Dense(embedding_dim, activation='relu', name="image_adapter")
        text_adapter = Dense(embedding_dim, activation='relu', name="text_adapter")

        # Apply adapters
        A_I = image_adapter(F_proj_I)
        A_T = text_adapter(F_proj_T)

        # Compute final representations with residual connections
        F_I = alpha * A_I + (1 - alpha) * F_proj_I
        F_T = alpha * A_T + (1 - alpha) * F_proj_T

        return F_I.numpy(), F_T.numpy()
    else:
        print("No valid embeddings generated.")
        return np.array([]), np.array([])

# Call the updated function
image_embeds, text_embeds = get_clip_embeddings_with_adapters(
    df['new_image_path'].tolist(),
    df['meme_text_masked'].tolist(),
    embedding_dim=1024, 
    alpha=0.5
)
# Out:
# Processing Batches: 100%|██████████| 305/305 [06:00<00:00,  1.18s/it]

# %%
labels = df['label'].values
num_classes = len(np.unique(labels))
num_classes
# Out:
# 2

# %%
# modality fusion

fused_embeds = image_embeds * text_embeds 
fused_embeds
# Out:
# array([[-2.3957216e-06, -9.9531643e-04, -5.3626229e-04, ...,
#          1.5983936e-04, -6.7054125e-04, -2.0234462e-05],
#        [-7.0487251e-05, -7.1502611e-04, -4.0300493e-04, ...,
#          8.4723288e-05,  2.0161156e-04,  1.4512304e-03],
#        [-1.3071734e-04,  9.0184418e-05,  5.8500918e-05, ...,
#          5.5443251e-04, -4.5480632e-04,  8.1873652e-05],
#        ...,
#        [ 8.7885235e-07, -1.0198282e-04,  8.9929366e-05, ...,
#         -4.0195420e-05, -1.3031186e-04, -3.3897315e-05],
#        [ 3.4010940e-05, -7.0554734e-04,  2.5403553e-05, ...,
#         -3.6198835e-05,  1.7437225e-04,  1.5115466e-04],
#        [ 2.2208889e-05, -5.2534102e-04, -3.3660620e-04, ...,
#         -3.4186713e-05,  5.7124806e-04,  1.0398645e-04]], dtype=float32)

# %%
fused_embeds.shape
# Out:
# (9755, 1024)

# %%
# Create a stratified split
fused_embeds_train, fused_embeds_val, labels_train, labels_val = train_test_split(
    fused_embeds, labels, 
    test_size=0.2,        # 20% for validation
    stratify=labels,      # Ensures equal label distribution
    random_state=42       # For reproducibility
)

# %%
def classification_model(input_dim, num_classes=2):
    inputs = layers.Input(shape=(input_dim,))
    
    # First hidden layer
    x = layers.Dense(128, activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    
    # Second hidden layer
    x = layers.Dense(64, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    
    # Output layer
    outputs = layers.Dense(1, activation='sigmoid')(x)
    
    # Create the model
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

input_dim = fused_embeds.shape[1]
num_classes = 2

classification_model = classification_model(input_dim, num_classes)
classification_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
classification_model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 128)                 │         131,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_29               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_30               │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_37 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 140,289 (548.00 KB)
#  Trainable params: 139,905 (546.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
optimizer = Adam(learning_rate=0.001)
classification_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Define EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,         # Stop after 10 epochs of no improvement
    restore_best_weights=True  # Restore the weights of the best epoch
)

# Train the model with early stopping
history = classification_model.fit(
    fused_embeds_train, labels_train,
    validation_data=(fused_embeds_val, labels_val),  # Provide validation data
    epochs=100,
    batch_size=32,  # Optimal value 32
    shuffle=True,
    callbacks=[early_stopping]  # Include early stopping
)
# Out:
# Epoch 1/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6652 - loss: 0.6002 - val_accuracy: 0.5423 - val_loss: 0.6873
# Epoch 2/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7501 - loss: 0.5048 - val_accuracy: 0.7109 - val_loss: 0.6580
# Epoch 3/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7728 - loss: 0.4693 - val_accuracy: 0.7304 - val_loss: 0.5336
# Epoch 4/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7949 - loss: 0.4227 - val_accuracy: 0.7360 - val_loss: 0.5260
# Epoch 5/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.3962 - val_accuracy: 0.7453 - val_loss: 0.5795
# Epoch 6/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8357 - loss: 0.3646 - val_accuracy: 0.7263 - val_loss: 0.5726
# Epoch 7/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8597 - loss: 0.3229 - val_accuracy: 0.7417 - val_loss: 0.5814
# Epoch 8/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8804 - loss: 0.2788 - val_accuracy: 0.7371 - val_loss: 0.6179
# Epoch 9/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9000 - loss: 0.2361 - val_accuracy: 0.7237 - val_loss: 0.6936
# Epoch 10/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9166 - loss: 0.1983 - val_accuracy: 0.7237 - val_loss: 0.7697
# Epoch 11/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9423 - loss: 0.1591 - val_accuracy: 0.7227 - val_loss: 0.8734
# Epoch 12/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9496 - loss: 0.1422 - val_accuracy: 0.5197 - val_loss: 3.5123
# Epoch 13/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.1127 - val_accuracy: 0.7237 - val_loss: 0.9608
# Epoch 14/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9587 - loss: 0.1134 - val_accuracy: 0.7263 - val_loss: 0.9463

# %%
def plot_training_curves(history):
    # Extract metrics from history
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    
    epochs = range(1, len(loss) + 1)
    
    # Plot loss
    plt.figure(figsize=(16, 10))
    plt.subplot(2, 2, 1)
    plt.plot(epochs, loss, label='Training Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.title('Loss Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    # Plot accuracy
    plt.subplot(2, 2, 2)
    plt.plot(epochs, accuracy, label='Training Accuracy')
    plt.plot(epochs, val_accuracy, label='Validation Accuracy')
    plt.title('Accuracy Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()


plot_training_curves(history)

# %%
def build_classification_model_with_residual(input_dim, num_classes=2):
    inputs = layers.Input(shape=(input_dim,))
    
    # First block with residual connection
    x = layers.Dense(1024, activation='relu', 
                     kernel_regularizer=regularizers.l2(0.01))(inputs)  # L2 regularization
    x = layers.BatchNormalization()(x)  # Batch Normalization
    x = layers.Dropout(0.6)(x)  # Increased dropout for regularization
    residual1 = layers.Dense(1024, activation='relu',
                             kernel_regularizer=regularizers.l2(0.01))(x)
    residual1 = layers.BatchNormalization()(residual1)  # Batch Normalization
    x = layers.Add()([x, residual1])
    
    # Second block with residual connection
    x = layers.Dense(512, activation='relu', 
                     kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)  # Batch Normalization
    x = layers.Dropout(0.6)(x)  # Increased dropout for regularization
    residual2 = layers.Dense(512, activation='relu',
                             kernel_regularizer=regularizers.l2(0.01))(x)
    residual2 = layers.BatchNormalization()(residual2)  # Batch Normalization
    x = layers.Add()([x, residual2])
    
    # Third block with residual connection
    x = layers.Dense(256, activation='relu', 
                     kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)  # Batch Normalization
    x = layers.Dropout(0.6)(x)  # Increased dropout for regularization
    residual3 = layers.Dense(256, activation='relu',
                             kernel_regularizer=regularizers.l2(0.01))(x)
    residual3 = layers.BatchNormalization()(residual3)  # Batch Normalization
    x = layers.Add()([x, residual3])
    
    # Fourth block without residuals for bottleneck
    x = layers.Dense(128, activation='relu', 
                     kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)  # Batch Normalization
    x = layers.Dropout(0.6)(x)  # Dropout for regularization

    # Output layer: classification
    outputs = layers.Dense(1, activation='sigmoid')(x)

    # Create the model
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

input_dim = fused_embeds.shape[1]
num_classes = 2

classification_model = build_classification_model_with_residual(input_dim, num_classes=num_classes)
classification_model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7             │ (None, 1024)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_38 (Dense)          │ (None, 1024)           │      1,049,600 │ input_layer_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_31    │ (None, 1024)           │          4,096 │ dense_38[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_16 (Dropout)      │ (None, 1024)           │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_39 (Dense)          │ (None, 1024)           │      1,049,600 │ dropout_16[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_32    │ (None, 1024)           │          4,096 │ dense_39[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 1024)           │              0 │ dropout_16[0][0],      │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_40 (Dense)          │ (None, 512)            │        524,800 │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_33    │ (None, 512)            │          2,048 │ dense_40[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 512)            │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_41 (Dense)          │ (None, 512)            │        262,656 │ dropout_17[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_34    │ (None, 512)            │          2,048 │ dense_41[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 512)            │              0 │ dropout_17[0][0],      │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_42 (Dense)          │ (None, 256)            │        131,328 │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 256)            │          1,024 │ dense_42[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_18 (Dropout)      │ (None, 256)            │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_43 (Dense)          │ (None, 256)            │         65,792 │ dropout_18[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 256)            │          1,024 │ dense_43[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 256)            │              0 │ dropout_18[0][0],      │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_44 (Dense)          │ (None, 128)            │         32,896 │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 128)            │            512 │ dense_44[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_19 (Dropout)      │ (None, 128)            │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_45 (Dense)          │ (None, 1)              │            129 │ dropout_19[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 3,131,649 (11.95 MB)
#  Trainable params: 3,124,225 (11.92 MB)
#  Non-trainable params: 7,424 (29.00 KB)

# %%
optimizer = AdamW(learning_rate=1e-4)
classification_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,         # Stop after 10 epochs of no improvement
    restore_best_weights=True  # Restore the weights of the best epoch
)

history = classification_model.fit(
    fused_embeds_train, labels_train,
    validation_data=(fused_embeds_val, labels_val),  # Provide validation data
    epochs=100,
    batch_size=32,  # Optimal value 32
    shuffle=True,
    callbacks=[early_stopping]  # Include early stopping
)
# Out:
# Epoch 1/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - accuracy: 0.4983 - loss: 40.3101 - val_accuracy: 0.5423 - val_loss: 37.1695
# Epoch 2/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5481 - loss: 36.5723 - val_accuracy: 0.5423 - val_loss: 33.7525
# Epoch 3/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5513 - loss: 33.1922 - val_accuracy: 0.6253 - val_loss: 30.7057
# Epoch 4/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5651 - loss: 30.2456 - val_accuracy: 0.6530 - val_loss: 28.0489
# Epoch 5/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5966 - loss: 27.6409 - val_accuracy: 0.6591 - val_loss: 25.6903
# Epoch 6/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6125 - loss: 25.3062 - val_accuracy: 0.6699 - val_loss: 23.5572
# Epoch 7/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6298 - loss: 23.2014 - val_accuracy: 0.6791 - val_loss: 21.6148
# Epoch 8/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6432 - loss: 21.2838 - val_accuracy: 0.6797 - val_loss: 19.8328
# Epoch 9/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6396 - loss: 19.5320 - val_accuracy: 0.6848 - val_loss: 18.1770
# Epoch 10/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6555 - loss: 17.8761 - val_accuracy: 0.6945 - val_loss: 16.6349
# Epoch 11/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6585 - loss: 16.3508 - val_accuracy: 0.6827 - val_loss: 15.2061
# Epoch 12/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6635 - loss: 14.9299 - val_accuracy: 0.6920 - val_loss: 13.8546
# Epoch 13/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6707 - loss: 13.5779 - val_accuracy: 0.6771 - val_loss: 12.5972
# Epoch 14/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6824 - loss: 12.3110 - val_accuracy: 0.6971 - val_loss: 11.3988
# Epoch 15/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6934 - loss: 11.1324 - val_accuracy: 0.7012 - val_loss: 10.2689
# Epoch 16/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6894 - loss: 10.0246 - val_accuracy: 0.7053 - val_loss: 9.2237
# Epoch 17/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6928 - loss: 8.9829 - val_accuracy: 0.7053 - val_loss: 8.2416
# Epoch 18/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7140 - loss: 7.9906 - val_accuracy: 0.7032 - val_loss: 7.3193
# Epoch 19/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7216 - loss: 7.0809 - val_accuracy: 0.7196 - val_loss: 6.4651
# Epoch 20/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7221 - loss: 6.2472 - val_accuracy: 0.7084 - val_loss: 5.6994
# Epoch 21/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7275 - loss: 5.5037 - val_accuracy: 0.7084 - val_loss: 4.9963
# Epoch 22/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7277 - loss: 4.8078 - val_accuracy: 0.7191 - val_loss: 4.3517
# Epoch 23/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7248 - loss: 4.1796 - val_accuracy: 0.7222 - val_loss: 3.7852
# Epoch 24/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7314 - loss: 3.6496 - val_accuracy: 0.7253 - val_loss: 3.2857
# Epoch 25/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7409 - loss: 3.1412 - val_accuracy: 0.7278 - val_loss: 2.8506
# Epoch 26/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7493 - loss: 2.7258 - val_accuracy: 0.7242 - val_loss: 2.4797
# Epoch 27/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7441 - loss: 2.3696 - val_accuracy: 0.7268 - val_loss: 2.1588
# Epoch 28/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7464 - loss: 2.0568 - val_accuracy: 0.7371 - val_loss: 1.8805
# Epoch 29/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7556 - loss: 1.7858 - val_accuracy: 0.7401 - val_loss: 1.6521
# Epoch 30/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7616 - loss: 1.5579 - val_accuracy: 0.7386 - val_loss: 1.4738
# Epoch 31/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7703 - loss: 1.3754 - val_accuracy: 0.7114 - val_loss: 1.3315
# Epoch 32/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7745 - loss: 1.2243 - val_accuracy: 0.7248 - val_loss: 1.1875
# Epoch 33/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7845 - loss: 1.1102 - val_accuracy: 0.7278 - val_loss: 1.1022
# Epoch 34/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7776 - loss: 1.0115 - val_accuracy: 0.7376 - val_loss: 1.0079
# Epoch 35/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7916 - loss: 0.9170 - val_accuracy: 0.7365 - val_loss: 0.9674
# Epoch 36/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7841 - loss: 0.8699 - val_accuracy: 0.7412 - val_loss: 0.8976
# Epoch 37/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7841 - loss: 0.8034 - val_accuracy: 0.7278 - val_loss: 0.8739
# Epoch 38/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7853 - loss: 0.7728 - val_accuracy: 0.7309 - val_loss: 0.8360
# Epoch 39/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7873 - loss: 0.7482 - val_accuracy: 0.7181 - val_loss: 0.8206
# Epoch 40/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7952 - loss: 0.7002 - val_accuracy: 0.7314 - val_loss: 0.8052
# Epoch 41/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7884 - loss: 0.6878 - val_accuracy: 0.7427 - val_loss: 0.7686
# Epoch 42/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8093 - loss: 0.6639 - val_accuracy: 0.7289 - val_loss: 0.7632
# Epoch 43/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7908 - loss: 0.6683 - val_accuracy: 0.7278 - val_loss: 0.7686
# Epoch 44/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8055 - loss: 0.6349 - val_accuracy: 0.7304 - val_loss: 0.7611
# Epoch 45/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8048 - loss: 0.6233 - val_accuracy: 0.7294 - val_loss: 0.7429
# Epoch 46/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8041 - loss: 0.6104 - val_accuracy: 0.7314 - val_loss: 0.7572
# Epoch 47/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8132 - loss: 0.6065 - val_accuracy: 0.7391 - val_loss: 0.7589
# Epoch 48/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8131 - loss: 0.5942 - val_accuracy: 0.7345 - val_loss: 0.7599
# Epoch 49/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8151 - loss: 0.5834 - val_accuracy: 0.7176 - val_loss: 0.7475
# Epoch 50/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8233 - loss: 0.5879 - val_accuracy: 0.7232 - val_loss: 0.7556
# Epoch 51/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8168 - loss: 0.5888 - val_accuracy: 0.7381 - val_loss: 0.7679
# Epoch 52/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8321 - loss: 0.5677 - val_accuracy: 0.7242 - val_loss: 0.7523
# Epoch 53/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8308 - loss: 0.5686 - val_accuracy: 0.7278 - val_loss: 0.7475
# Epoch 54/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8248 - loss: 0.5639 - val_accuracy: 0.7371 - val_loss: 0.7749
# Epoch 55/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8199 - loss: 0.5739 - val_accuracy: 0.7125 - val_loss: 0.7597

# %%
plot_training_curves_and_metrics(history)

# %% [markdown]
# ### CLIP feature adapters as trainable layers

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Add, Lambda, Concatenate
from tensorflow.keras.models import Model

# %%
def get_clip_embeddings(image_paths, texts, batch_size=32):
    """Extract raw CLIP embeddings for images and texts."""
    image_embeds = []
    text_embeds = []

    # Iterate through batches
    for i in tqdm(range(0, len(image_paths), batch_size), desc="Processing Batches"):
        batch_image_paths = image_paths[i:i + batch_size]
        batch_texts = texts[i:i + batch_size]

        try:
            # Load images
            images = [Image.open(p).convert("RGB") for p in batch_image_paths]
        except Exception as e:
            print(f"Error loading images in batch {i // batch_size + 1}. Skipping batch.")
            print(f"Error: {e}")
            continue  # Skip this batch if there's an error loading images

        try:
            # Get CLIP embeddings
            inputs = clip_processor(text=batch_texts, images=images, return_tensors="tf", padding=True)
            outputs = clip_model(**inputs)

            image_embeds.append(outputs.image_embeds.numpy())
            text_embeds.append(outputs.text_embeds.numpy())
        except Exception as e:
            print(f"Error processing batch {i // batch_size + 1}. Skipping batch.")
            print(f"Error: {e}")
            continue  # Skip this batch if there's an error processing text and images

    # Concatenate all batches
    if image_embeds and text_embeds:
        return np.concatenate(image_embeds, axis=0), np.concatenate(text_embeds, axis=0)
    else:
        print("No valid embeddings generated.")
        return np.array([]), np.array([])

# Get embeddings without projection layers
image_embeds, text_embeds = get_clip_embeddings(
    df['new_image_path'].tolist(),
    df['meme_text_masked'].tolist()
)
# Out:
# Processing Batches:   0%|          | 0/305 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (117 > 77). Running this sequence through the model will result in indexing errors
# Processing Batches: 100%|██████████| 305/305 [06:15<00:00,  1.23s/it]

# %%
def build_feature_projection(input_layer, embedding_dim, name):
    """Trainable projection layer to map inputs to feature space."""
    proj_layer = Dense(embedding_dim, name=f"{name}_projection")
    return proj_layer(input_layer)

def build_feature_adapter(proj_feature, embedding_dim, alpha, name):
    """Feature adapter with a residual connection."""
    adapter_layer = Dense(embedding_dim, activation='relu', name=f"{name}_adapter")
    adapted_feature = adapter_layer(proj_feature)

    # Residual connection (mixing original and adapted feature)
    mixed_feature = Add()([
        Lambda(lambda x: alpha * x)(adapted_feature),
        Lambda(lambda x: (1 - alpha) * x)(proj_feature)
    ])
    return mixed_feature

def build_multimodal_model(image_embed_dim, text_embed_dim, embedding_dim=1024, alpha=0.5):
    """Creates a multimodal model integrating image & text features with adapters."""
    
    # Define Inputs
    image_input = Input(shape=(image_embed_dim,), name="image_input")
    text_input = Input(shape=(text_embed_dim,), name="text_input")

    # Trainable Feature Projections
    F_proj_I = build_feature_projection(image_input, embedding_dim, "image")
    F_proj_T = build_feature_projection(text_input, embedding_dim, "text")

    # Feature Adapters with Residual Connections
    F_I = build_feature_adapter(F_proj_I, embedding_dim, alpha, "image")
    F_T = build_feature_adapter(F_proj_T, embedding_dim, alpha, "text")

    # Merge Features
    merged_features = Concatenate()([F_I, F_T])

    # Classification Layer
    output_layer = Dense(1, activation="sigmoid", name="classification_output")(merged_features)

    # Define Model
    model = Model(inputs=[image_input, text_input], outputs=output_layer, name="Multimodal_CLIP_Model")

    # Compile Model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])
    
    return model

# Example: Define input dimensions based on your embeddings
image_embed_dim = 512  # Replace with actual shape
text_embed_dim = 512  # Replace with actual shape

# Build Model
model = build_multimodal_model(image_embed_dim, text_embed_dim)

# Summary
model.summary()
# Out:
# Model: "Multimodal_CLIP_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image_input (InputLayer)  │ (None, 512)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_input (InputLayer)   │ (None, 512)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_projection (Dense)  │ (None, 1024)           │        525,312 │ image_input[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_projection (Dense)   │ (None, 1024)           │        525,312 │ text_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_adapter (Dense)     │ (None, 1024)           │      1,049,600 │ image_projection[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_adapter (Dense)      │ (None, 1024)           │      1,049,600 │ text_projection[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_12 (Lambda)        │ (None, 1024)           │              0 │ image_adapter[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_13 (Lambda)        │ (None, 1024)           │              0 │ image_projection[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_14 (Lambda)        │ (None, 1024)           │              0 │ text_adapter[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_15 (Lambda)        │ (None, 1024)           │              0 │ text_projection[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 1024)           │              0 │ lambda_12[0][0],       │
# │                           │                        │                │ lambda_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 1024)           │              0 │ lambda_14[0][0],       │
# │                           │                        │                │ lambda_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 2048)           │              0 │ add_6[0][0],           │
# │ (Concatenate)             │                        │                │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ classification_output     │ (None, 1)              │          2,049 │ concatenate_3[0][0]    │
# │ (Dense)                   │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 3,151,873 (12.02 MB)
#  Trainable params: 3,151,873 (12.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
image_embeds_train, image_embeds_val, text_embeds_train, text_embeds_val, labels_train, labels_val = train_test_split(
    image_embeds, text_embeds, df['label'].values, 
    test_size=0.2,  # 20% for validation
    random_state=42,  # Reproducibility
    stratify=df['label'].values  # Maintain label distribution
)

# %%
# Define optimizer
optimizer = AdamW(learning_rate=1e-4)

# Compile the classification model
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Early Stopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,         # Stop after 10 epochs of no improvement
    restore_best_weights=True  # Restore best epoch's weights
)

history = model.fit(
    [image_embeds_train, text_embeds_train],  # Correct: Use train data only
    labels_train,  
    validation_data=([image_embeds_val, text_embeds_val], labels_val),  # Validation data
    epochs=20, 
    batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8321 - loss: 0.3553 - val_accuracy: 0.7432 - val_loss: 0.5354
# Epoch 2/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8512 - loss: 0.3393 - val_accuracy: 0.7447 - val_loss: 0.5440
# Epoch 3/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8446 - loss: 0.3419 - val_accuracy: 0.7453 - val_loss: 0.5471
# Epoch 4/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8452 - loss: 0.3360 - val_accuracy: 0.7463 - val_loss: 0.5578
# Epoch 5/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8510 - loss: 0.3320 - val_accuracy: 0.7335 - val_loss: 0.5602
# Epoch 6/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8588 - loss: 0.3241 - val_accuracy: 0.7273 - val_loss: 0.5888
# Epoch 7/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8576 - loss: 0.3173 - val_accuracy: 0.7391 - val_loss: 0.5671
# Epoch 8/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8564 - loss: 0.3289 - val_accuracy: 0.7314 - val_loss: 0.5805
# Epoch 9/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8618 - loss: 0.3070 - val_accuracy: 0.7340 - val_loss: 0.5867
# Epoch 10/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8654 - loss: 0.3065 - val_accuracy: 0.7309 - val_loss: 0.5848
# Epoch 11/20
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8765 - loss: 0.2912 - val_accuracy: 0.7294 - val_loss: 0.6266

# %%
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Concatenate, Add

def build_feature_projection(input_tensor, embedding_dim, modality_name):
    """Trainable linear projection layer for feature embeddings."""
    x = Dense(embedding_dim, name=f"{modality_name}_projection")(input_tensor)
    x = BatchNormalization(name=f"{modality_name}_proj_bn")(x)  # Batch Norm
    return x

def build_feature_adapter(proj_features, embedding_dim, alpha, modality_name):
    """Feature adapter with skip connection, dropout, and batch normalization."""
    adapted_features = Dense(embedding_dim, activation="relu", name=f"{modality_name}_adapter")(proj_features)
    adapted_features = BatchNormalization(name=f"{modality_name}_adapter_bn")(adapted_features)  # Batch Norm
    adapted_features = Dropout(0.6, name=f"{modality_name}_adapter_dropout")(adapted_features)  # Dropout
    
    # Residual Connection (Skip Connection)
    fused_features = Add(name=f"{modality_name}_skip_connection")([
        tf.keras.layers.Lambda(lambda x: alpha * x)(adapted_features),
        tf.keras.layers.Lambda(lambda x: (1 - alpha) * x)(proj_features)
    ])
    
    return fused_features

def build_multimodal_model(image_embed_dim, text_embed_dim, embedding_dim=1024, alpha=0.5):
    """Creates a multimodal model integrating image & text features with adapters, batchnorm, dropout, and skip connections."""
    
    # Define Inputs
    image_input = Input(shape=(image_embed_dim,), name="image_input")
    text_input = Input(shape=(text_embed_dim,), name="text_input")

    # Feature Projections
    F_proj_I = build_feature_projection(image_input, embedding_dim, "image")
    F_proj_T = build_feature_projection(text_input, embedding_dim, "text")

    # Feature Adapters with Skip Connections
    F_I = build_feature_adapter(F_proj_I, embedding_dim, alpha, "image")
    F_T = build_feature_adapter(F_proj_T, embedding_dim, alpha, "text")

    # Merge Image & Text Features
    merged_features = Concatenate(name="merged_features")([F_I, F_T])

    # Fully Connected Layers with Dropout & BatchNorm
    x = Dense(512, activation="relu", name="fc_1")(merged_features)
    x = BatchNormalization(name="fc_1_bn")(x)
    x = Dropout(0.6, name="fc_1_dropout")(x)

    x = Dense(256, activation="relu", name="fc_2")(x)
    x = BatchNormalization(name="fc_2_bn")(x)
    x = Dropout(0.6, name="fc_2_dropout")(x)

    # Classification Output
    output_layer = Dense(1, activation="sigmoid", name="classification_output")(x)

    # Define & Compile Model
    model = Model(inputs=[image_input, text_input], outputs=output_layer, name="Multimodal_CLIP_Model")
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])
    
    return model


image_embed_dim = 512  # Example dimension
text_embed_dim = 512  # Example dimension
model = build_multimodal_model(image_embed_dim, text_embed_dim)
model.summary()
# Out:
# Model: "Multimodal_CLIP_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image_input (InputLayer)  │ (None, 512)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_input (InputLayer)   │ (None, 512)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_projection (Dense)  │ (None, 1024)           │        525,312 │ image_input[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_projection (Dense)   │ (None, 1024)           │        525,312 │ text_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_proj_bn             │ (None, 1024)           │          4,096 │ image_projection[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_proj_bn              │ (None, 1024)           │          4,096 │ text_projection[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_adapter (Dense)     │ (None, 1024)           │      1,049,600 │ image_proj_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_adapter (Dense)      │ (None, 1024)           │      1,049,600 │ text_proj_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_adapter_bn          │ (None, 1024)           │          4,096 │ image_adapter[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_adapter_bn           │ (None, 1024)           │          4,096 │ text_adapter[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_adapter_dropout     │ (None, 1024)           │              0 │ image_adapter_bn[0][0] │
# │ (Dropout)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_adapter_dropout      │ (None, 1024)           │              0 │ text_adapter_bn[0][0]  │
# │ (Dropout)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_28 (Lambda)        │ (None, 1024)           │              0 │ image_adapter_dropout… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_29 (Lambda)        │ (None, 1024)           │              0 │ image_proj_bn[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_30 (Lambda)        │ (None, 1024)           │              0 │ text_adapter_dropout[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_31 (Lambda)        │ (None, 1024)           │              0 │ text_proj_bn[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_skip_connection     │ (None, 1024)           │              0 │ lambda_28[0][0],       │
# │ (Add)                     │                        │                │ lambda_29[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ text_skip_connection      │ (None, 1024)           │              0 │ lambda_30[0][0],       │
# │ (Add)                     │                        │                │ lambda_31[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ merged_features           │ (None, 2048)           │              0 │ image_skip_connection… │
# │ (Concatenate)             │                        │                │ text_skip_connection[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ fc_1 (Dense)              │ (None, 512)            │      1,049,088 │ merged_features[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ fc_1_bn                   │ (None, 512)            │          2,048 │ fc_1[0][0]             │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ fc_1_dropout (Dropout)    │ (None, 512)            │              0 │ fc_1_bn[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ fc_2 (Dense)              │ (None, 256)            │        131,328 │ fc_1_dropout[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ fc_2_bn                   │ (None, 256)            │          1,024 │ fc_2[0][0]             │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ fc_2_dropout (Dropout)    │ (None, 256)            │              0 │ fc_2_bn[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ classification_output     │ (None, 1)              │            257 │ fc_2_dropout[0][0]     │
# │ (Dense)                   │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 4,349,953 (16.59 MB)
#  Trainable params: 4,340,225 (16.56 MB)
#  Non-trainable params: 9,728 (38.00 KB)

# %%
# Define optimizer
optimizer = AdamW(learning_rate=1e-4)

# Compile the classification model
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Early Stopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,         # Stop after 10 epochs of no improvement
    restore_best_weights=True  # Restore best epoch's weights
)

history = model.fit(
    [image_embeds_train, text_embeds_train],  # Correct: Use train data only
    labels_train,  
    validation_data=([image_embeds_val, text_embeds_val], labels_val),  # Validation data
    epochs=100, 
    batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.5327 - loss: 1.0421 - val_accuracy: 0.6586 - val_loss: 0.6585
# Epoch 2/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6196 - loss: 0.8329 - val_accuracy: 0.7191 - val_loss: 0.5694
# Epoch 3/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6688 - loss: 0.7528 - val_accuracy: 0.7355 - val_loss: 0.5323
# Epoch 4/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6882 - loss: 0.7039 - val_accuracy: 0.7494 - val_loss: 0.5258
# Epoch 5/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7059 - loss: 0.6500 - val_accuracy: 0.7458 - val_loss: 0.5220
# Epoch 6/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7243 - loss: 0.6092 - val_accuracy: 0.7581 - val_loss: 0.5129
# Epoch 7/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7300 - loss: 0.5965 - val_accuracy: 0.7529 - val_loss: 0.5102
# Epoch 8/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7446 - loss: 0.5580 - val_accuracy: 0.7570 - val_loss: 0.5047
# Epoch 9/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7610 - loss: 0.5233 - val_accuracy: 0.7581 - val_loss: 0.4974
# Epoch 10/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7545 - loss: 0.5278 - val_accuracy: 0.7632 - val_loss: 0.4958
# Epoch 11/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7678 - loss: 0.4968 - val_accuracy: 0.7642 - val_loss: 0.4898
# Epoch 12/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7795 - loss: 0.4853 - val_accuracy: 0.7627 - val_loss: 0.4996
# Epoch 13/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7885 - loss: 0.4543 - val_accuracy: 0.7606 - val_loss: 0.5013
# Epoch 14/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7908 - loss: 0.4419 - val_accuracy: 0.7596 - val_loss: 0.4970
# Epoch 15/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8019 - loss: 0.4230 - val_accuracy: 0.7581 - val_loss: 0.4995
# Epoch 16/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8083 - loss: 0.4213 - val_accuracy: 0.7576 - val_loss: 0.5068
# Epoch 17/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8167 - loss: 0.3984 - val_accuracy: 0.7586 - val_loss: 0.4987
# Epoch 18/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8112 - loss: 0.4000 - val_accuracy: 0.7632 - val_loss: 0.5039
# Epoch 19/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8299 - loss: 0.3733 - val_accuracy: 0.7632 - val_loss: 0.5041
# Epoch 20/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8409 - loss: 0.3684 - val_accuracy: 0.7586 - val_loss: 0.5188
# Epoch 21/100
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8398 - loss: 0.3475 - val_accuracy: 0.7581 - val_loss: 0.5151

# %% [markdown]
# - high dropout rate of 0.6
# - AdamW optimizer
# - batch normalization
# - l2 regularization
# - skip connections

# %% [markdown]
# ## Model Performance Evaluation

# %%
test_df = pd.read_csv('/kaggle/input/testing-memes/val_dataset.csv', index_col=0)
test_df.head()
# Out:
#       id                   img  label  \
# 0   8291  ./data/img/08291.png      1
# 1  46971  ./data/img/46971.png      1
# 2   3745  ./data/img/03745.png      1
# 3  83745  ./data/img/83745.png      1
# 4  80243  ./data/img/80243.png      1
#
#                                                 text  \
# 0              white people is this a shooting range
# 1                              bravery at its finest
# 2  your order comes to $37.50 and your white priv...
# 3  it is time.. to send these parasites back to t...
# 4                             mississippi wind chime
#
#                                       processed_text      processed_img_path
# 0              white people is this a shooting range  ./val_images/08291.png
# 1                              bravery at its finest  ./val_images/46971.png
# 2  your order comes to $37.50 and your white priv...  ./val_images/03745.png
# 3  it is time.. to send these parasites back to t...  ./val_images/83745.png
# 4                             mississippi wind chime  ./val_images/80243.png

# %%
prefix = '/kaggle/input/testing-memes/val_images/'
test_df['processed_img_path'] = test_df['processed_img_path'].str.replace("./", prefix)
test_df.head()
# Out:
#       id                   img  label  \
# 0   8291  ./data/img/08291.png      1
# 1  46971  ./data/img/46971.png      1
# 2   3745  ./data/img/03745.png      1
# 3  83745  ./data/img/83745.png      1
# 4  80243  ./data/img/80243.png      1
#
#                                                 text  \
# 0              white people is this a shooting range
# 1                              bravery at its finest
# 2  your order comes to $37.50 and your white priv...
# 3  it is time.. to send these parasites back to t...
# 4                             mississippi wind chime
#
#                                       processed_text  \
# 0              white people is this a shooting range
# 1                              bravery at its finest
# 2  your order comes to $37.50 and your white priv...
# 3  it is time.. to send these parasites back to t...
# 4                             mississippi wind chime
#
#                                   processed_img_path
# 0  /kaggle/input/testing-memes/val_images/val_ima...
# 1  /kaggle/input/testing-memes/val_images/val_ima...
# 2  /kaggle/input/testing-memes/val_images/val_ima...
# 3  /kaggle/input/testing-memes/val_images/val_ima...
# 4  /kaggle/input/testing-memes/val_images/val_ima...

# %%
labels_test = test_df['label']

# %%
image_embeds, text_embeds = get_clip_embeddings_with_adapters(
    test_df['processed_img_path'].tolist(),
    test_df['processed_text'].tolist(),  
    embedding_dim=1024, 
    alpha=0.5
)

test_fused_embeds = image_embeds * text_embeds 
test_fused_embeds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-77d197340f4e> in <cell line: 1>()
# ----> 1 image_embeds, text_embeds = get_clip_embeddings_with_adapters(
#       2     test_df['processed_img_path'].tolist(),
#       3     test_df['processed_text'].tolist(),
#       4     embedding_dim=1024,
#       5     alpha=0.5
#
# NameError: name 'get_clip_embeddings_with_adapters' is not defined

# %%
y_pred_prob = classification_model.predict(test_fused_embeds)
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step

# %%
y_pred_prob = classification_model.predict(test_fused_embeds)
y_pred = (y_pred_prob > 0.5).astype(int)

from pprint import pprint
pprint(classification_report(labels_test, y_pred))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ('              precision    recall  f1-score   support\n'
#  '\n'
#  '           0       0.56      0.10      0.16       250\n'
#  '           1       0.51      0.92      0.65       250\n'
#  '\n'
#  '    accuracy                           0.51       500\n'
#  '   macro avg       0.53      0.51      0.41       500\n'
#  'weighted avg       0.53      0.51      0.41       500\n')

# %%
cm = confusion_matrix(labels_test, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Compute ROC curve
fpr, tpr, _ = roc_curve(labels_test, y_pred_prob)  # Use probabilities for ROC curve
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal reference line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

# Get precision, recall, and thresholds from predicted probabilities
precision, recall, thresholds = precision_recall_curve(labels_test, y_pred_prob)

# Plot Precision-Recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', color='b', label='Precision-Recall Curve')
plt.fill_between(recall, precision, color='skyblue', alpha=0.3)
plt.title('Precision-Recall Curve', fontsize=14)
plt.xlabel('Recall', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.grid(True)
plt.legend(loc='lower left')
plt.show()

# %%
harmful_probs = y_pred_prob[labels_test == 1]  # Harmful memes (label=1)
harmless_probs = y_pred_prob[labels_test == 0]  # Harmless memes (label=0)

# Plotting the distribution
plt.figure(figsize=(8, 6))
sns.kdeplot(harmful_probs.squeeze(), label='Harmful', fill=True, color='red', alpha=0.5)
sns.kdeplot(harmless_probs.squeeze(), label='Harmless', fill=True, color='green', alpha=0.5)
plt.title('Class-Separation Probability Distribution', fontsize=14)
plt.xlabel('Predicted Probability', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sorted_probs = np.sort(y_pred_prob)[::-1]
sorted_labels = labels_test[np.argsort(y_pred_prob)[::-1]]

# Cumulative gain calculation
cumulative_gains = np.cumsum(sorted_labels) / np.sum(sorted_labels)

# Plotting the Cumulative Gain chart
plt.figure(figsize=(8, 6))
plt.plot(np.linspace(0, 100, len(cumulative_gains)), cumulative_gains * 100, label="Model")
plt.plot([0, 100], [0, 100], linestyle='--', label="Random", color='gray')  # Random guessing line
plt.title('Cumulative Gain Chart', fontsize=14)
plt.xlabel('% of Tested Memes', fontsize=12)
plt.ylabel('% of Harmful Memes Detected', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-9e3e42135d6d> in <cell line: 2>()
#       1 sorted_probs = np.sort(y_pred_prob)[::-1]
# ----> 2 sorted_labels = labels_test[np.argsort(y_pred_prob)[::-1]]
#       3
#       4 # Cumulative gain calculation
#       5 cumulative_gains = np.cumsum(sorted_labels) / np.sum(sorted_labels)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1151             return self._get_rows_with_mask(key)
#    1152
# -> 1153         return self._get_with(key)
#    1154
#    1155     def _get_with(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_with(self, key)
#    1178             #  (i.e. self.iloc) or label-based (i.e. self.loc)
#    1179             if not self.index._should_fallback_to_positional:
# -> 1180                 return self.loc[key]
#    1181             else:
#    1182                 warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1416             if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#    1417                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1418                     raise ValueError("Cannot index with multidimensional key")
#    1419
#    1420                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
from sklearn.calibration import calibration_curve

# Calculate calibration curve
fraction_of_positives, mean_predicted_value = calibration_curve(labels_test, y_pred_prob, n_bins=10)

# Plotting the calibration curve
plt.figure(figsize=(8, 6))
plt.plot(mean_predicted_value, fraction_of_positives, marker='.', color='b', label='Model')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfectly calibrated', color='gray')  # Ideal line
plt.title('Calibration Plot', fontsize=14)
plt.xlabel('Mean Predicted Probability', fontsize=12)
plt.ylabel('Fraction of Positives', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Testing against adverserial attacks

# %%
def add_gaussian_noise(image_path, noise_level=10):
    image = cv2.imread(image_path)
    noise = np.random.normal(0, noise_level, image.shape).astype(np.uint8)
    noisy_image = cv2.add(image, noise)
    
    # Convert back to PIL format for compatibility with your pipeline
    return Image.fromarray(cv2.cvtColor(noisy_image, cv2.COLOR_BGR2RGB))

# Example: Apply noise to a sample image
sample_image_path = test_df['processed_img_path'].iloc[0]
noisy_image = add_gaussian_noise(sample_image_path)

# Show original and noisy images
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(Image.open(sample_image_path))
ax[0].set_title("Original Image")
ax[0].axis("off")

ax[1].imshow(noisy_image)
ax[1].set_title("Noisy Image")
ax[1].axis("off")

plt.show()

# %%
def get_clip_embeddings_with_adapters(image_inputs, texts, batch_size=32, embedding_dim=1024, alpha=0.5):
    image_embeds = []
    text_embeds = []

    for i in tqdm(range(0, len(image_inputs), batch_size), desc="Processing Batches"):
        batch_images = image_inputs[i:i + batch_size]
        batch_texts = texts[i:i + batch_size]

        # Load images only if they are file paths
        try:
            if isinstance(batch_images[0], str):  # If paths are given, load them
                images = [Image.open(p).convert("RGB") for p in batch_images]
            else:  # Otherwise, assume images are already pre-processed
                images = batch_images
        except Exception as e:
            print(f"Error loading images in batch {i // batch_size + 1}. Example images: {batch_images[:2]}")
            print(f"Error: {e}")
            continue  # Skip this batch if there's an error loading images

        try:
            # Get CLIP model embeddings
            inputs = clip_processor(text=batch_texts, images=images, return_tensors="tf", padding=True)
            outputs = clip_model(**inputs)

            image_embeds.append(outputs.image_embeds.numpy())
            text_embeds.append(outputs.text_embeds.numpy())
        except Exception as e:
            print(f"Error processing batch {i // batch_size + 1}. Example texts: {batch_texts[:2]}")
            print(f"Error: {e}")
            continue  # Skip this batch if there's an error processing text and images

    # Concatenate all batches
    if image_embeds and text_embeds:
        image_embeds = np.concatenate(image_embeds, axis=0)
        text_embeds = np.concatenate(text_embeds, axis=0)

        # Define linear projection layers
        image_proj_layer = Dense(embedding_dim, name="image_projection")
        text_proj_layer = Dense(embedding_dim, name="text_projection")

        # Apply projection
        F_proj_I = image_proj_layer(image_embeds)
        F_proj_T = text_proj_layer(text_embeds)

        # Define feature adapters
        image_adapter = Dense(embedding_dim, activation='relu', name="image_adapter")
        text_adapter = Dense(embedding_dim, activation='relu', name="text_adapter")

        # Apply adapters
        A_I = image_adapter(F_proj_I)
        A_T = text_adapter(F_proj_T)

        # Compute final representations with residual connections
        F_I = alpha * A_I + (1 - alpha) * F_proj_I
        F_T = alpha * A_T + (1 - alpha) * F_proj_T

        return F_I.numpy(), F_T.numpy()
    else:
        print("No valid embeddings generated.")
        return np.array([]), np.array([])

# %%
# Run inference on the original and noisy image
original_pred = classification_model.predict(get_clip_embeddings_with_adapters([sample_image_path], ["sample text"])[0])
print(f"Original Prediction: {original_pred}")

noisy_pred = classification_model.predict(get_clip_embeddings_with_adapters([noisy_image], ["sample text"])[0])
print(f"Noisy Image Prediction: {noisy_pred}")
# Out:
# Processing Batches: 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Original Prediction: [[1.]]
# Processing Batches: 100%|██████████| 1/1 [00:00<00:00,  2.90it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Noisy Image Prediction: [[1.]]

# %% [markdown]
# ## Explainability

# %% [markdown]
# # Exporting Best Model

# %%
# classification_model.save('classification_model.h5') 

converter = tf.lite.TFLiteConverter.from_keras_model(classification_model)
tflite_model = converter.convert()

# Save the converted TFLite model
with open('best_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpgxpalmmu/assets
# INFO:tensorflow:Assets written to: /tmp/tmpgxpalmmu/assets
# Saved artifact at '/tmp/tmpgxpalmmu'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1024), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   140283672841904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140289157982944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680365856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680358464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680362336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680360400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680373424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680370256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283672667312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140285858787952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140284036858800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283672666784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283672853696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680359696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680366032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680372016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680374304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680358992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283680362864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679412592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679413120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679412416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679409072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679411536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679419456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679416288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679419632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679421392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679416816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679415584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679416640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679379824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679380352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679379648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679376304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679378768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679386688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679383520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679386864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679388624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679384048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679382816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283679383872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140283674137120: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1737432219.200128    1680 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1737432219.200152    1680 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-01-21 04:03:39.200979: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpgxpalmmu
# 2025-01-21 04:03:39.203100: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-01-21 04:03:39.203122: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpgxpalmmu
# I0000 00:00:1737432219.223305    1680 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# 2025-01-21 04:03:39.228662: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-01-21 04:03:39.403179: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpgxpalmmu
# 2025-01-21 04:03:39.445861: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 244888 microseconds.

# %%
# Load the TFLite model
interpreter = tf.lite.Interpreter(model_path='best_model.tflite')
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
